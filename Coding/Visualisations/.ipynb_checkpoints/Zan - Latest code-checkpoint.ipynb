# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import hvplot.pandas
from scipy.stats import linregress
import scipy.stats

# %%
Country_data_df=pd.read_csv("output_data/Cleaned_Countries_Data.csv", index_col="Unnamed: 0")
Country_data_df
# Out:
#        Country   Waste  Recycled    Lat   Long  GDP (billion USD)  \
# 0      Algeria   12.38      0.99  28.00   3.00             169.91
# 1       Angola    4.21      0.00 -12.30  18.30              97.26
# 2     Botswana    0.21      0.00 -22.00  24.00              18.34
# 3        Benin    0.69      0.17   9.30   2.15              10.31
# 4      Burundi    1.87      0.00  -3.30  30.00               3.03
# ..         ...     ...       ...    ...    ...                ...
# 177  Sri Lanka    2.63      0.34   7.00  81.00              84.02
# 178      India  168.40      8.42  20.00  77.00            2835.93
# 179   Maldives    0.21      0.00   3.15  73.00               4.50
# 180      Nepal    1.77      0.00  28.00  84.00              24.88
# 181   Pakistan   30.76      2.46  30.00  70.00             253.18
#
#      Real GDP 2020 (billion USD)  Real GDP Per Capita 2020  \
# 0                         468.40                   10700.0
# 1                         203.71                    6200.0
# 2                          37.72                   16000.0
# 3                          40.29                    3300.0
# 4                           8.69                     700.0
# ..                           ...                       ...
# 177                       274.80                   12500.0
# 178                      8443.36                    6100.0
# 179                         7.05                   13000.0
# 180                       110.72                    3800.0
# 181                      1021.13                    4600.0
#
#      Wasted Generated Annually (million tons)  \
# 0                                       12.38
# 1                                        4.21
# 2                                        0.21
# 3                                        0.69
# 4                                        1.87
# ..                                        ...
# 177                                      2.63
# 178                                    168.40
# 179                                      0.21
# 180                                      1.77
# 181                                     30.76
#
#      Wasted Recycled Annually (million tons)  ...  Net Waste  \
# 0                                       0.99  ...      11.39
# 1                                       0.00  ...        NaN
# 2                                       0.00  ...        NaN
# 3                                       0.17  ...       0.52
# 4                                       0.00  ...        NaN
# ..                                       ...  ...        ...
# 177                                     0.34  ...       2.29
# 178                                     8.42  ...     159.98
# 179                                     0.00  ...        NaN
# 180                                     0.00  ...        NaN
# 181                                     2.46  ...      28.30
#
#      Particulate Matter Emissions (micrograms per m3)  \
# 0                                               35.17
# 1                                               27.95
# 2                                               21.24
# 3                                               33.11
# 4                                               35.61
# ..                                                ...
# 177                                             15.25
# 178                                             65.20
# 179                                              7.63
# 180                                             94.33
# 181                                             55.21
#
#      C02 Emissions (megatons)  Methane  Emissions (megatons)  \
# 0                      150.01                          49.94
# 1                       34.69                          23.28
# 2                        6.34                           5.73
# 3                        6.48                           5.80
# 4                        0.50                           1.42
# ..                        ...                            ...
# 177                     23.36                          10.95
# 178                   2407.67                         559.11
# 179                      1.44                           0.14
# 180                      9.11                          41.15
# 181                    201.15                         142.12
#
#      Electricity by Unclean Energy (%)  Electricity by Clean Energy (%)  \
# 0                                 98.9                              1.1
# 1                                 28.4                             71.6
# 2                                 99.8                              0.2
# 3                                 96.9                              3.1
# 4                                 33.3                             66.7
# ..                                 ...                              ...
# 177                               64.0                             36.0
# 178                               75.5                             24.5
# 179                               99.6                              0.4
# 180                                0.0                            100.0
# 181                               55.2                             44.8
#
#      Urban Population (%)  Net Migration  Total Agreement  Development Status
# 0                    74.8          -0.82            -0.82          Developing
# 1                    68.1          -0.19            -0.19          Developing
# 2                    72.2           2.81             2.81          Developing
# 3                    49.5           0.24             0.24                 LDC
# 4                    14.4           7.09             7.09                 LDC
# ..                    ...            ...              ...                 ...
# 177                  19.0          -1.22            -1.22          Developing
# 178                  35.9           0.16             0.16          Developing
# 179                  41.5         -12.78           -12.78          Developing
# 180                  21.5          -4.21            -4.21                 LDC
# 181                  37.7          -0.96            -0.96          Developing
#
# [182 rows x 21 columns]

# %%
# Groupby main dataframe based upon 'Development Status' and apply agg to Waste Generated 
Waste_data = Country_data_df.groupby('Development Status').agg({'Wasted Generated Annually (million tons)': ['sum', 'mean', 'median', 'var', 'std', 'sem']})

# Remove multi-index and flatten headers so data can be referenced in charts
Waste_data.columns = Waste_data.columns.droplevel(0)
Waste_data = Waste_data.reset_index()
Waste_data
# Out:
#   Development Status      sum       mean  median          var        std  \
# 0          Developed   531.46  16.608125   4.435  2098.171796  45.805805
# 1         Developing  1126.07  10.426574   2.095   796.318740  28.219120
# 2                LDC   104.13   2.479286   1.830     7.954621   2.820394
#
#         sem
# 0  8.097399
# 1  2.715386
# 2  0.435196

# %%
# GDP vs Waste Generated

fig1, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

# Define the data to be shown in chart
data = Waste_data['mean']

# Define pieces of the pie
labels = ['Developed', 'Developing', 'LDC']

# The colors of each section of the pie chart
colors = ["green", "orange", "red"]

# Tells matplotlib to separate the Developed section from the others (each number references a pie slab)
explode = (.1, 0, 0)

# Create pie chart based upon Development Status and C02 Emissions
plt.title("Waste Generated per Country Type", bbox={'facecolor':'0.8', 'pad':5})

plt.pie(data, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a146491070>,
#   <matplotlib.patches.Wedge at 0x1a146491a00>,
#   <matplotlib.patches.Wedge at 0x1a14649c3d0>],
#  [Text(-1.1767798548295096, -0.23492376054251804, 'Developed'),
#   Text(1.0975420397103373, -0.07349470095505205, 'Developing'),
#   Text(0.2869381059905064, 1.0619164389586315, 'LDC')],
#  [Text(-0.6864549153172139, -0.13703886031646884, '56.3%'),
#   Text(0.5986592943874567, -0.04008801870275566, '35.3%'),
#   Text(0.15651169417663982, 0.5792271485228899, '8.4%')])

# %%
# Groupby main dataframe based upon 'Development Status' and apply agg to Waste Recycled Annually
Recycle_data = Country_data_df.groupby('Development Status').agg({'Wasted Recycled Annually (million tons)': ['sum', 'mean', 'median', 'var', 'std', 'sem']})

# Remove multi-index and flatten headers so data can be referenced in charts
Recycle_data.columns = Recycle_data.columns.droplevel(0)
Recycle_data = Recycle_data.reset_index()
Recycle_data
# Out:
#   Development Status     sum      mean  median         var        std  \
# 0          Developed  169.37  5.292813    1.15  257.019008  16.031812
# 1         Developing   65.05  0.602315    0.01    1.809502   1.345177
# 2                LDC    2.64  0.062857    0.00    0.021099   0.145255
#
#         sem
# 0  2.834051
# 1  0.129440
# 2  0.022413

# %%
# GDP vs Waste Recycled

fig2, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

# Define the data to be shown in chart
data = Recycle_data['mean']

# Define pieces of the pie
labels = ['Developed', 'Developing', 'LDC']

# The colors of each section of the pie chart
colors = ["green", "orange", "red"]

# Tells matplotlib to separate the Developed section from the others (each number references a pie slab)
explode = (.1,0,0)

# Create pie chart based upon Development Status and C02 Emissions
plt.title("Waste Recycled per Country Type", bbox={'facecolor':'0.8', 'pad':5})

plt.pie(data, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a1464e5520>,
#   <matplotlib.patches.Wedge at 0x1a1464e5eb0>,
#   <matplotlib.patches.Wedge at 0x1a1464f0880>],
#  [Text(-0.412310646374734, -1.1269427362941071, 'Developed'),
#   Text(0.4119763689120961, 1.0199389547703357, 'Developing'),
#   Text(0.03645173253851313, 1.09939586646255, 'LDC')],
#  [Text(-0.24051454371859485, -0.657383262838229, '88.8%'),
#   Text(0.2247143830429615, 0.5563303389656375, '10.1%'),
#   Text(0.01988276320282534, 0.5996704726159363, '1.1%')])

# %%
# Groupby main dataframe based upon 'Development Status' and apply agg to Waste Generated
Clean_data = Country_data_df.groupby('Development Status').agg({'Electricity by Clean Energy (%)': ['sum', 'mean', 'median', 'var', 'std', 'sem']})

# Remove multi-index and flatten headers so data can be referenced in charts
Clean_data.columns = Clean_data.columns.droplevel(0)
Clean_data = Clean_data.reset_index()
Clean_data
# Out:
#   Development Status     sum       mean  median          var        std  \
# 0          Developed  1517.3  47.415625   47.60  1325.107167  36.402021
# 1         Developing  3870.7  35.839815   27.95   909.961110  30.165562
# 2                LDC  1855.8  44.185714   33.80  1458.130035  38.185469
#
#         sem
# 0  6.435029
# 1  2.902683
# 2  5.892146

# %%
# GDP vs Clean Enery

fig3, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

# Define the data to be shown in chart
data = Clean_data['mean']

# Define pieces of the pie
labels = ['Developed', 'Developing', 'LDC']

# The colors of each section of the pie chart
colors = ["green", "orange", "red"]

# Tells matplotlib to separate the Developed section from the others (each number references a pie slab)
explode = (.1,0,0)

# Create pie chart based upon Development Status and C02 Emissions
plt.title("Clean Energy per Country Type", bbox={'facecolor':'0.8', 'pad':5})

plt.pie(data, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a14659b0d0>,
#   <matplotlib.patches.Wedge at 0x1a14659ba60>,
#   <matplotlib.patches.Wedge at 0x1a1465a6430>],
#  [Text(-1.104365230801337, 0.46944375275117867, 'Developed'),
#   Text(0.08749124682304202, -1.0965150622446322, 'Developing'),
#   Text(0.9749007421262059, 0.5094786972992819, 'LDC')],
#  [Text(-0.6442130513007799, 0.27384218910485425, '37.2%'),
#   Text(0.04772249826711382, -0.5980991248607084, '28.1%'),
#   Text(0.5317640411597486, 0.2778974712541537, '34.7%')])
